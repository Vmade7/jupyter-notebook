# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'D:\Jupyter notebook\titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print("\n=== 缺失值统计 ===")
missing_values = df.isnull().sum()
missing_percent = (missing_values / len(df)) * 100
missing_df = pd.DataFrame({'缺失数量': missing_values, '缺失比例(%)': missing_percent.round(2)})
print(missing_df)
# Out:
# === 缺失值统计 ===
#              缺失数量  缺失比例(%)
# PassengerId     0     0.00
# Survived        0     0.00
# Pclass          0     0.00
# Name            0     0.00
# Sex             0     0.00
# Age           177    19.87
# SibSp           0     0.00
# Parch           0     0.00
# Ticket          0     0.00
# Fare            0     0.00
# Cabin         687    77.10
# Embarked        2     0.22

# %%
print("\n== 缺失值处理策略 ===")
for col in missing_df.index:
    if missing_df.loc[col, '缺失数量'] > 0:
        percent = missing_df.loc[col, '缺失比例(%)']
        
        if percent < 5:  # 小于5%删除行
            print(f"{col}: 缺失比例{percent}% < 5%，直接删除该行")
            
            
        elif percent > 30:  # 大于30%删除列
            print(f"{col}: 缺失比例{percent}% > 30%，删除整列")
            
        else:  # 中间值填充
            print(f"{col}: 5% < 缺失比例{percent}% < 30%，分组填充")
# Out:
# == 缺失值处理策略 ===
# Age: 5% < 缺失比例19.87% < 30%，分组填充
# Cabin: 缺失比例77.1% > 30%，删除整列
# Embarked: 缺失比例0.22% < 5%，直接删除该行

# %%
if 'Cabin' in df.columns:
    df.drop('Cabin', axis=1, inplace=True)

# %%
# Age填充：按性别和舱位分组中位数
df['Age'] = df.groupby(['Sex', 'Pclass'])['Age'].transform(
    lambda x: x.fillna(x.median())
)

# 删除 Embarked 列有缺失值的行
df.dropna(subset=['Embarked'], inplace=True)

# %%
print("\n=== 缺失值再次统计 ===")
missing_values = df.isnull().sum()
missing_percent = (missing_values / len(df)) * 100
missing_df = pd.DataFrame({'缺失数量': missing_values, '缺失比例(%)': missing_percent.round(2)})
print(missing_df)
# Out:
# === 缺失值再次统计 ===
#              缺失数量  缺失比例(%)
# PassengerId     0      0.0
# Survived        0      0.0
# Pclass          0      0.0
# Name            0      0.0
# Sex             0      0.0
# Age             0      0.0
# SibSp           0      0.0
# Parch           0      0.0
# Ticket          0      0.0
# Fare            0      0.0
# Embarked        0      0.0

# %%
numeric_cols = ['Age', 'Fare', 'SibSp', 'Parch']
for col in numeric_cols:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
 # 四舍五入转整数
df['Age'] = df['Age'].round().astype(int)

# %%
print("=== 年龄异常值再次检查 ===")
print(f"小数年龄数量：{len(df[~df['Age'].astype(int).eq(df['Age'])])}")
print(f"负数年龄数量：{len(df[df['Age'] < 0])}")
# Out:
# === 年龄异常值再次检查 ===
# 小数年龄数量：0
# 负数年龄数量：0

# %%
# 导入可视化库
import seaborn as sns
import matplotlib.pyplot as plt

#  散点图：查看Age和Fare的关系
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Fare', data=df)
plt.title('Age vs Fare')
plt.show()

# 4.2 箱线图：查看不同船舱等级(Pclass)下的票价(Fare)分布
plt.figure(figsize=(8, 6))
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title('Fare Distribution by Pclass')
plt.show()


#柱状图 - 不同舱位等级（Pclass）的乘客数量
plt.figure(figsize=(8, 6))
sns.countplot(x='Pclass', data=df)
plt.title('Number of Passengers by Pclass')
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.show()



#饼图 - 不同登船港口（Embarked）的乘客比例
embarked_counts = df['Embarked'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(embarked_counts, labels=embarked_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Passenger Proportion by Embarked Port')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(
    x='Pclass', 
    hue='Sex', 
    data=df, 
    palette={'male': '#e74c3c', 'female': '#2ecc71'}  # 男红女绿
)
plt.xlabel('Passenger Class', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Passenger Count by Class and Sex', fontsize=14, pad=20)
plt.legend(title='Sex', loc='upper right')
plt.show()
